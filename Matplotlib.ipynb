# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
yaslistesi=[10,20,30,30,30,40,50,60,70,75]

# %%
kilolistesi=[20,60,80,85,86,87,70,90,95,90]

# %%
numpyyaslistesi=np.array(yaslistesi)
numpykilolistesi=np.array(kilolistesi)

# %%
numpykilolistesi
# Out:
# array([20, 60, 80, 85, 86, 87, 70, 90, 95, 90])

# %%
numpyyaslistesi
# Out:
# array([10, 20, 30, 30, 30, 40, 50, 60, 70, 75])

# %%
plt.plot(numpyyaslistesi,numpykilolistesi,"b")

# %%
plt.plot(numpyyaslistesi,numpykilolistesi,"y")
plt.xlabel("Yas")
plt.ylabel("Kilo")
plt.title("Kilo'nu Yaşa Göre Değişm Grafiği")
#plt.show()
# Out:
# Text(0.5, 1.0, "Kilo'nu Yaşa Göre Değişm Grafiği")

# %%
plt.plot(numpykilolistesi,numpyyaslistesi,"y")

# %%
numpydizisi1=np.linspace (0,10,20)

# %%
numpydizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpydizisi2=numpydizisi1**3

# %%
numpydizisi2
# Out:
# array([0.00000000e+00, 1.45793847e-01, 1.16635078e+00, 3.93643388e+00,
#        9.33080624e+00, 1.82242309e+01, 3.14914711e+01, 5.00072897e+01,
#        7.46464499e+01, 1.06283715e+02, 1.45793847e+02, 1.94051611e+02,
#        2.51931768e+02, 3.20309083e+02, 4.00058318e+02, 4.92054235e+02,
#        5.97171599e+02, 7.16285173e+02, 8.50269719e+02, 1.00000000e+03])

# %%
plt.plot(numpydizisi1,numpydizisi2,"g")

# %%
plt.plot(numpydizisi1,numpydizisi2,"g--")

# %%
plt.plot(numpydizisi1,numpydizisi2,"g*-")

# %%
plt.subplot(1,2,1)
plt.plot(numpydizisi1,numpydizisi2,"r*-")
plt.subplot(1,2,2) # 1 sıra olacak, 2 kolon olacak, şu an 2. grafiği çiziyorum
plt.plot(numpydizisi2,numpydizisi1,"g--")

# %%
benimfigure=plt.figure()
figureaxes=benimfigure.add_axes([0.8,0.8,0.3,0.3])
figureaxes.plot(numpydizisi1,numpydizisi2,"g")
figureaxes.set_xlabel("X ekseni veri ismi")
figureaxes.set_ylabel("Y ekseni Veri İsmi")
figureaxes.set_title("Grafik Başlığı")
# Out:
# Text(0.5, 1.0, 'Grafik Başlığı')

# %% [markdown]
# # İç içe Grafikler

# %%
figure2=plt.figure()

eksen1=figure2.add_axes([0.1,0.1,0.9,0.9])
eksen2=figure2.add_axes([0.2,0.3,0.3,0.3])

eksen1.plot(numpydizisi1,numpydizisi2, "g")
eksen1.set_xlabel("X Ekseni")
eksen1.set_ylabel("Y Ekseni")
eksen1.set_title("Ana Grafik Başlık")

eksen2.plot(numpydizisi2,numpydizisi1,"b")
eksen2.set_xlabel("X ekseni")
eksen2.set_ylabel("Y ekseni")
eksen2.set_title("Küçük Grafik Başlık")
# Out:
# Text(0.5, 1.0, 'Küçük Grafik Başlık')

# %%
benimfigure

# %%
(benimfigure,benimeksen) = plt.subplots()
benimeksen.plot(numpydizisi2,numpydizisi2,"b")

# %%
(benimfigure,benimeksen) = plt.subplots(nrows=1,ncols=2)
benimeksen.plot(numpydizisi2,numpydizisi2,"b")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_193708/930537158.py in <module>
#       1 (benimfigure,benimeksen) = plt.subplots(nrows=1,ncols=2)
# ----> 2 benimeksen.plot(numpydizisi2,numpydizisi2,"b")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
type(benimeksen)
# Out:
# numpy.ndarray

# %%
(benimfigure,benimeksenler) = plt.subplots(nrows=1,ncols=2)
type(benimeksenler)

for eksen in benimeksenler:
    eksen.plot(numpydizisi1,numpydizisi2,"g")
    eksen.set_xlabel("X ekseni")
    
plt.tight_layout()   
#benimfigure

# %% [markdown]
# # Görsel Geliştirmeler

# %%
yenifigur=plt.figure(figsize=(3,3))

yenieksen=yenifigur.add_axes([0.1,0.1,0.9,0.9])

yenieksen.plot(numpydizisi1,numpydizisi1**2,label="numpydizisi **2")
yenieksen.plot(numpydizisi1,numpydizisi1 **3, label="numpydizisi **3")
yenieksen.legend(loc=0)

# %%
yenifigur.savefig("benimfigur.png", dpi=200)

# %%
#Yeni Örnek

# %%
numpydizisi1=np.linspace(1.10,20)

# %%
numpydizisi
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpydizisi2=numpydizisi1**2

# %%
(benimfigur,benimeksen)=plt.subplots()
benimeksen.plot(numpydizisi1,numpydizisi2,"g")
benimeksen.plot(numpydizisi2,numpydizisi1,"b")

# %%
(yenifigur,yenieksen)=plt.subplots()
yenieksen.plot(numpydizisi1,numpydizisi1 + 2,color="blue",linewidth=1.0)
yenieksen.plot(numpydizisi1,numpydizisi1 + 3,color="yellow",linewidth=5.0)

yenieksen.plot(numpydizisi1,numpydizisi1 + 4,color="red",linestyle="-.")
yenieksen.plot(numpydizisi1,numpydizisi1 + 5,color="black",linestyle=":")
yenieksen.plot(numpydizisi1,numpydizisi1 + 6,color="green",linestyle="--")

yenieksen.plot(numpydizisi1,numpydizisi1 + 4,color="black",linestyle="--", marker="o", markersize=4,markerfacecolor="red")

# %% [markdown]
# # Farklı grafik çeşitleri

# %% [markdown]
# # 1. Scatter

# %%
plt.scatter(numpydizisi1,numpydizisi2)

# %% [markdown]
# # 2. Histogram

# %%
yenidizi=np.random.randint(0,100,50)

# %%
yenidizi
# Out:
# array([79, 41, 36, 94, 10, 78,  9,  8, 53, 93, 14, 31,  6, 48, 91, 63, 14,
#        26, 56,  7, 45, 82, 12, 92, 59, 48, 92, 83, 12, 44, 86, 91, 35, 48,
#        85, 64, 30, 34, 24, 28, 87, 60, 84, 52, 56, 91, 98,  1, 35, 27])

# %%
plt.hist(yenidizi)
# Out:
# (array([6., 4., 5., 5., 6., 5., 3., 1., 7., 8.]),
#  array([ 1. , 10.7, 20.4, 30.1, 39.8, 49.5, 59.2, 68.9, 78.6, 88.3, 98. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # 3.Boxplot

# %%
plt.boxplot(yenidizi*2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e7110cee0>,
#   <matplotlib.lines.Line2D at 0x1e7111b2b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e7111b640>,
#   <matplotlib.lines.Line2D at 0x1e7111b9d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e7110cb50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e7111bd60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e71128130>],
#  'means': []}
